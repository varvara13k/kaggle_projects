# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/journey-springfield/sample_submission.csv
# /kaggle/input/journey-springfield/characters_illustration.png
# /kaggle/input/journey-springfield/testset/testset/img516.jpg
# /kaggle/input/journey-springfield/testset/testset/img254.jpg
# /kaggle/input/journey-springfield/testset/testset/img263.jpg
# /kaggle/input/journey-springfield/testset/testset/img659.jpg
# /kaggle/input/journey-springfield/testset/testset/img575.jpg
# /kaggle/input/journey-springfield/testset/testset/img0.jpg
# /kaggle/input/journey-springfield/testset/testset/img403.jpg
# /kaggle/input/journey-springfield/testset/testset/img976.jpg
# /kaggle/input/journey-springfield/testset/testset/img224.jpg
# /kaggle/input/journey-springfield/testset/testset/img985.jpg
# /kaggle/input/journey-springfield/testset/testset/img514.jpg
# /kaggle/input/journey-springfield/testset/testset/img170.jpg
# /kaggle/input/journey-springfield/testset/testset/img212.jpg
# /kaggle/input/journey-springfield/testset/testset/img280.jpg
# /kaggle/input/journey-springfield/testset/testset/img77.jpg
# /kaggle/input/journey-springfield/testset/testset/img340.jpg
# /kaggle/input/journey-springfield/testset/testset/img521.jpg
# /kaggle/input/journey-springfield/testset/testset/img154.jpg
# /kaggle/input/journey-springfield/testset/testset/img498.jpg
# /kaggle/input/journey-springfield/testset/testset/img42.jpg
# /kaggle/input/journey-springfield/testset/testset/img342.jpg
# /kaggle/input/journey-springfield/testset/testset/img691.jpg
# /kaggle/input/journey-springfield/testset/testset/img286.jpg
# /kaggle/input/journey-springfield/testset/testset/img144.jpg
# /kaggle/input/journey-springfield/testset/testset/img729.jpg
# /kaggle/input/journey-springfield/testset/testset/img150.jpg
# /kaggle/input/journey-springfield/testset/testset/img396.jpg
# /kaggle/input/journey-springfield/testset/testset/img328.jpg
# /kaggle/input/journey-springfield/testset/testset/img788.jpg
# /kaggle/input/journey-springfield/testset/testset/img551.jpg
# /kaggle/input/journey-springfield/testset/testset/img290.jpg
# /kaggle/input/journey-springfield/testset/testset/img297.jpg
# /kaggle/input/journey-springfield/testset/testset/img289.jpg
# /kaggle/input/journey-springfield/testset/testset/img338.jpg
# /kaggle/input/journey-springfield/testset/testset/img868.jpg
# /kaggle/input/journey-springfield/testset/testset/img431.jpg
# /kaggle/input/journey-springfield/testset/testset/img331.jpg
# /kaggle/input/journey-springfield/testset/testset/img383.jpg
# /kaggle/input/journey-springfield/testset/testset/img749.jpg
# /kaggle/input/journey-springfield/testset/testset/img139.jpg
# /kaggle/input/journey-springfield/testset/testset/img285.jpg
# /kaggle/input/journey-springfield/testset/testset/img243.jpg
# /kaggle/input/journey-springfield/testset/testset/img752.jpg
# /kaggle/input/journey-springfield/testset/testset/img491.jpg
# /kaggle/input/journey-springfield/testset/testset/img501.jpg
# /kaggle/input/journey-springfield/testset/testset/img593.jpg
# /kaggle/input/journey-springfield/testset/testset/img210.jpg
# /kaggle/input/journey-springfield/testset/testset/img148.jpg
# /kaggle/input/journey-springfield/testset/testset/img915.jpg
# /kaggle/input/journey-springfield/testset/testset/img975.jpg
# /kaggle/input/journey-springfield/testset/testset/img162.jpg
# /kaggle/input/journey-springfield/testset/testset/img16.jpg
# /kaggle/input/journey-springfield/testset/testset/img930.jpg
# /kaggle/input/journey-springfield/testset/testset/img130.jpg
# /kaggle/input/journey-springfield/testset/testset/img524.jpg
# /kaggle/input/journey-springfield/testset/testset/img544.jpg
# /kaggle/input/journey-springfield/testset/testset/img888.jpg
# /kaggle/input/journey-springfield/testset/testset/img136.jpg
# /kaggle/input/journey-springfield/testset/testset/img234.jpg
# /kaggle/input/journey-springfield/testset/testset/img476.jpg
# /kaggle/input/journey-springfield/testset/testset/img613.jpg
# /kaggle/input/journey-springfield/testset/testset/img683.jpg
# /kaggle/input/journey-springfield/testset/testset/img323.jpg
# /kaggle/input/journey-springfield/testset/testset/img204.jpg
# /kaggle/input/journey-springfield/testset/testset/img855.jpg
# /kaggle/input/journey-springfield/testset/testset/img273.jpg
# /kaggle/input/journey-springfield/testset/testset/img663.jpg
# /kaggle/input/journey-springfield/testset/testset/img128.jpg
# /kaggle/input/journey-springfield/testset/testset/img164.jpg
# /kaggle/input/journey-springfield/testset/testset/img579.jpg
# /kaggle/input/journey-springfield/testset/testset/img660.jpg
# /kaggle/input/journey-springfield/testset/testset/img948.jpg
# /kaggle/input/journey-springfield/testset/testset/img188.jpg
# /kaggle/input/journey-springfield/testset/testset/img964.jpg
# /kaggle/input/journey-springfield/testset/testset/img424.jpg
# /kaggle/input/journey-springfield/testset/testset/img900.jpg
# /kaggle/input/journey-springfield/testset/testset/img83.jpg
# /kaggle/input/journey-springfield/testset/testset/img418.jpg
# /kaggle/input/journey-springfield/testset/testset/img643.jpg
# /kaggle/input/journey-springfield/testset/testset/img452.jpg
# /kaggle/input/journey-springfield/testset/testset/img563.jpg
# /kaggle/input/journey-springfield/testset/testset/img854.jpg
# /kaggle/input/journey-springfield/testset/testset/img718.jpg
# /kaggle/input/journey-springfield/testset/testset/img217.jpg
# /kaggle/input/journey-springfield/testset/testset/img810.jpg
# /kaggle/input/journey-springfield/testset/testset/img921.jpg
# /kaggle/input/journey-springfield/testset/testset/img726.jpg
# /kaggle/input/journey-springfield/testset/testset/img33.jpg
# /kaggle/input/journey-springfield/testset/testset/img844.jpg
# /kaggle/input/journey-springfield/testset/testset/img796.jpg
# /kaggle/input/journey-springfield/testset/testset/img872.jpg
# /kaggle/input/journey-springfield/testset/testset/img428.jpg
# /kaggle/input/journey-springfield/testset/testset/img960.jpg
# /kaggle/input/journey-springfield/testset/testset/img9.jpg
# /kaggle/input/journey-springfield/testset/testset/img917.jpg
# /kaggle/input/journey-springfield/testset/testset/img676.jpg
# /kaggle/input/journey-springfield/testset/testset/img981.jpg
# /kaggle/input/journey-springfield/testset/testset/img745.jpg
# /kaggle/input/journey-springfield/testset/testset/img591.jpg
# /kaggle/input/journey-springfield/testset/testset/img733.jpg
# /kaggle/input/journey-springfield/testset/testset/img314.jpg
# /kaggle/input/journey-springfield/testset/testset/img113.jpg
# /kaggle/input/journey-springfield/testset/testset/img296.jpg
# /kaggle/input/journey-springfield/testset/testset/img721.jpg
# /kaggle/input/journey-springfield/testset/testset/img568.jpg
# /kaggle/input/journey-springfield/testset/testset/img651.jpg
# /kaggle/input/journey-springfield/testset/testset/img324.jpg
# /kaggle/input/journey-springfield/testset/testset/img685.jpg
# /kaggle/input/journey-springfield/testset/testset/img894.jpg
# /kaggle/input/journey-springfield/testset/testset/img192.jpg
# /kaggle/input/journey-springfield/testset/testset/img876.jpg
# /kaggle/input/journey-springfield/testset/testset/img451.jpg
# /kaggle/input/journey-springfield/testset/testset/img447.jpg
# /kaggle/input/journey-springfield/testset/testset/img510.jpg
# /kaggle/input/journey-springfield/testset/testset/img258.jpg
# /kaggle/input/journey-springfield/testset/testset/img21.jpg
# /kaggle/input/journey-springfield/testset/testset/img206.jpg
# /kaggle/input/journey-springfield/testset/testset/img416.jpg
# /kaggle/input/journey-springfield/testset/testset/img159.jpg
# /kaggle/input/journey-springfield/testset/testset/img946.jpg
# /kaggle/input/journey-springfield/testset/testset/img649.jpg
# /kaggle/input/journey-springfield/testset/testset/img365.jpg
# /kaggle/input/journey-springfield/testset/testset/img119.jpg
# /kaggle/input/journey-springfield/testset/testset/img966.jpg
# /kaggle/input/journey-springfield/testset/testset/img36.jpg
# /kaggle/input/journey-springfield/testset/testset/img479.jpg
# /kaggle/input/journey-springfield/testset/testset/img58.jpg
# /kaggle/input/journey-springfield/testset/testset/img401.jpg
# /kaggle/input/journey-springfield/testset/testset/img640.jpg
# /kaggle/input/journey-springfield/testset/testset/img461.jpg
# /kaggle/input/journey-springfield/testset/testset/img143.jpg
# /kaggle/input/journey-springfield/testset/testset/img740.jpg
# /kaggle/input/journey-springfield/testset/testset/img337.jpg
# /kaggle/input/journey-springfield/testset/testset/img194.jpg
# /kaggle/input/journey-springfield/testset/testset/img974.jpg
# /kaggle/input/journey-springfield/testset/testset/img779.jpg
# /kaggle/input/journey-springfield/testset/testset/img636.jpg
# /kaggle/input/journey-springfield/testset/testset/img459.jpg
# /kaggle/input/journey-springfield/testset/testset/img85.jpg
# /kaggle/input/journey-springfield/testset/testset/img552.jpg
# /kaggle/input/journey-springfield/testset/testset/img134.jpg
# /kaggle/input/journey-springfield/testset/testset/img895.jpg
# /kaggle/input/journey-springfield/testset/testset/img607.jpg
# /kaggle/input/journey-springfield/testset/testset/img244.jpg
# /kaggle/input/journey-springfield/testset/testset/img681.jpg
# /kaggle/input/journey-springfield/testset/testset/img482.jpg
# /kaggle/input/journey-springfield/testset/testset/img89.jpg
# /kaggle/input/journey-springfield/testset/testset/img175.jpg
# /kaggle/input/journey-springfield/testset/testset/img961.jpg
# /kaggle/input/journey-springfield/testset/testset/img566.jpg
# /kaggle/input/journey-springfield/testset/testset/img434.jpg
# /kaggle/input/journey-springfield/testset/testset/img973.jpg
# /kaggle/input/journey-springfield/testset/testset/img184.jpg
# /kaggle/input/journey-springfield/testset/testset/img540.jpg
# /kaggle/input/journey-springfield/testset/testset/img907.jpg
# /kaggle/input/journey-springfield/testset/testset/img133.jpg
# /kaggle/input/journey-springfield/testset/testset/img264.jpg
# /kaggle/input/journey-springfield/testset/testset/img395.jpg
# /kaggle/input/journey-springfield/testset/testset/img763.jpg
# /kaggle/input/journey-springfield/testset/testset/img312.jpg
# /kaggle/input/journey-springfield/testset/testset/img197.jpg
# /kaggle/input/journey-springfield/testset/testset/img274.jpg
# /kaggle/input/journey-springfield/testset/testset/img339.jpg
# /kaggle/input/journey-springfield/testset/testset/img967.jpg
# /kaggle/input/journey-springfield/testset/testset/img821.jpg
# /kaggle/input/journey-springfield/testset/testset/img988.jpg
# /kaggle/input/journey-springfield/testset/testset/img160.jpg
# /kaggle/input/journey-springfield/testset/testset/img426.jpg
# /kaggle/input/journey-springfield/testset/testset/img737.jpg
# /kaggle/input/journey-springfield/testset/testset/img247.jpg
# /kaggle/input/journey-springfield/testset/testset/img692.jpg
# /kaggle/input/journey-springfield/testset/testset/img376.jpg
# /kaggle/input/journey-springfield/testset/testset/img87.jpg
# /kaggle/input/journey-springfield/testset/testset/img40.jpg
# /kaggle/input/journey-springfield/testset/testset/img279.jpg
# /kaggle/input/journey-springfield/testset/testset/img790.jpg
# /kaggle/input/journey-springfield/testset/testset/img251.jpg
# /kaggle/input/journey-springfield/testset/testset/img835.jpg
# /kaggle/input/journey-springfield/testset/testset/img17.jpg
# /kaggle/input/journey-springfield/testset/testset/img351.jpg
# /kaggle/input/journey-springfield/testset/testset/img437.jpg
# /kaggle/input/journey-springfield/testset/testset/img509.jpg
# /kaggle/input/journey-springfield/testset/testset/img490.jpg
# /kaggle/input/journey-springfield/testset/testset/img523.jpg
# /kaggle/input/journey-springfield/testset/testset/img183.jpg
# /kaggle/input/journey-springfield/testset/testset/img519.jpg
# /kaggle/input/journey-springfield/testset/testset/img45.jpg
# /kaggle/input/journey-springfield/testset/testset/img965.jpg
# /kaggle/input/journey-springfield/testset/testset/img910.jpg
# /kaggle/input/journey-springfield/testset/testset/img97.jpg
# /kaggle/input/journey-springfield/testset/testset/img268.jpg
# /kaggle/input/journey-springfield/testset/testset/img677.jpg
# /kaggle/input/journey-springfield/testset/testset/img699.jpg
# /kaggle/input/journey-springfield/testset/testset/img493.jpg
# /kaggle/input/journey-springfield/testset/testset/img420.jpg
# /kaggle/input/journey-springfield/testset/testset/img187.jpg
# /kaggle/input/journey-springfield/testset/testset/img2.jpg
# /kaggle/input/journey-springfield/testset/testset/img379.jpg
# /kaggle/input/journey-springfield/testset/testset/img141.jpg
# /kaggle/input/journey-springfield/testset/testset/img242.jpg
# /kaggle/input/journey-springfield/testset/testset/img511.jpg
# /kaggle/input/journey-springfield/testset/testset/img269.jpg
# /kaggle/input/journey-springfield/testset/testset/img140.jpg
# /kaggle/input/journey-springfield/testset/testset/img385.jpg
# /kaggle/input/journey-springfield/testset/testset/img390.jpg
# /kaggle/input/journey-springfield/testset/testset/img893.jpg
# /kaggle/input/journey-springfield/testset/testset/img18.jpg
# /kaggle/input/journey-springfield/testset/testset/img327.jpg
# /kaggle/input/journey-springfield/testset/testset/img421.jpg
# /kaggle/input/journey-springfield/testset/testset/img48.jpg
# /kaggle/input/journey-springfield/testset/testset/img664.jpg
# /kaggle/input/journey-springfield/testset/testset/img777.jpg
# /kaggle/input/journey-springfield/testset/testset/img672.jpg
# /kaggle/input/journey-springfield/testset/testset/img195.jpg
# /kaggle/input/journey-springfield/testset/testset/img177.jpg
# /kaggle/input/journey-springfield/testset/testset/img924.jpg
# /kaggle/input/journey-springfield/testset/testset/img151.jpg
# /kaggle/input/journey-springfield/testset/testset/img760.jpg
# /kaggle/input/journey-springfield/testset/testset/img282.jpg
# /kaggle/input/journey-springfield/testset/testset/img803.jpg
# /kaggle/input/journey-springfield/testset/testset/img27.jpg
# /kaggle/input/journey-springfield/testset/testset/img764.jpg
# /kaggle/input/journey-springfield/testset/testset/img816.jpg
# /kaggle/input/journey-springfield/testset/testset/img51.jpg
# /kaggle/input/journey-springfield/testset/testset/img39.jpg
# /kaggle/input/journey-springfield/testset/testset/img811.jpg
# /kaggle/input/journey-springfield/testset/testset/img525.jpg
# /kaggle/input/journey-springfield/testset/testset/img413.jpg
# /kaggle/input/journey-springfield/testset/testset/img349.jpg
# /kaggle/input/journey-springfield/testset/testset/img326.jpg
# /kaggle/input/journey-springfield/testset/testset/img840.jpg
# /kaggle/input/journey-springfield/testset/testset/img881.jpg
# /kaggle/input/journey-springfield/testset/testset/img846.jpg
# /kaggle/input/journey-springfield/testset/testset/img435.jpg
# /kaggle/input/journey-springfield/testset/testset/img446.jpg
# /kaggle/input/journey-springfield/testset/testset/img799.jpg
# /kaggle/input/journey-springfield/testset/testset/img711.jpg
# /kaggle/input/journey-springfield/testset/testset/img353.jpg
# /kaggle/input/journey-springfield/testset/testset/img356.jpg
# /kaggle/input/journey-springfield/testset/testset/img505.jpg
# /kaggle/input/journey-springfield/testset/testset/img870.jpg
# /kaggle/input/journey-springfield/testset/testset/img725.jpg
# /kaggle/input/journey-springfield/testset/testset/img599.jpg
# /kaggle/input/journey-springfield/testset/testset/img304.jpg
# /kaggle/input/journey-springfield/testset/testset/img565.jpg
# /kaggle/input/journey-springfield/testset/testset/img903.jpg
# /kaggle/input/journey-springfield/testset/testset/img229.jpg
# /kaggle/input/journey-springfield/testset/testset/img57.jpg
# /kaggle/input/journey-springfield/testset/testset/img422.jpg
# /kaggle/input/journey-springfield/testset/testset/img405.jpg
# /kaggle/input/journey-springfield/testset/testset/img547.jpg
# /kaggle/input/journey-springfield/testset/testset/img647.jpg
# /kaggle/input/journey-springfield/testset/testset/img838.jpg
# /kaggle/input/journey-springfield/testset/testset/img700.jpg
# /kaggle/input/journey-springfield/testset/testset/img475.jpg
# /kaggle/input/journey-springfield/testset/testset/img362.jpg
# /kaggle/input/journey-springfield/testset/testset/img205.jpg
# /kaggle/input/journey-springfield/testset/testset/img550.jpg
# /kaggle/input/journey-springfield/testset/testset/img625.jpg
# /kaggle/input/journey-springfield/testset/testset/img260.jpg
# /kaggle/input/journey-springfield/testset/testset/img904.jpg
# /kaggle/input/journey-springfield/testset/testset/img728.jpg
# /kaggle/input/journey-springfield/testset/testset/img742.jpg
# /kaggle/input/journey-springfield/testset/testset/img574.jpg
# /kaggle/input/journey-springfield/testset/testset/img348.jpg
# /kaggle/input/journey-springfield/testset/testset/img7.jpg
# /kaggle/input/journey-springfield/testset/testset/img832.jpg
# /kaggle/input/journey-springfield/testset/testset/img582.jpg
# /kaggle/input/journey-springfield/testset/testset/img751.jpg
# /kaggle/input/journey-springfield/testset/testset/img833.jpg
# /kaggle/input/journey-springfield/testset/testset/img220.jpg
# /kaggle/input/journey-springfield/testset/testset/img837.jpg
# /kaggle/input/journey-springfield/testset/testset/img680.jpg
# /kaggle/input/journey-springfield/testset/testset/img783.jpg
# /kaggle/input/journey-springfield/testset/testset/img82.jpg
# /kaggle/input/journey-springfield/testset/testset/img235.jpg
# /kaggle/input/journey-springfield/testset/testset/img653.jpg
# /kaggle/input/journey-springfield/testset/testset/img784.jpg
# /kaggle/input/journey-springfield/testset/testset/img715.jpg
# /kaggle/input/journey-springfield/testset/testset/img52.jpg
# /kaggle/input/journey-springfield/testset/testset/img576.jpg
# /kaggle/input/journey-springfield/testset/testset/img502.jpg
# /kaggle/input/journey-springfield/testset/testset/img853.jpg
# /kaggle/input/journey-springfield/testset/testset/img926.jpg
# /kaggle/input/journey-springfield/testset/testset/img190.jpg
# /kaggle/input/journey-springfield/testset/testset/img735.jpg
# /kaggle/input/journey-springfield/testset/testset/img503.jpg
# /kaggle/input/journey-springfield/testset/testset/img272.jpg
# /kaggle/input/journey-springfield/testset/testset/img246.jpg
# /kaggle/input/journey-springfield/testset/testset/img414.jpg
# /kaggle/input/journey-springfield/testset/testset/img578.jpg
# /kaggle/input/journey-springfield/testset/testset/img822.jpg
# /kaggle/input/journey-springfield/testset/testset/img634.jpg
# /kaggle/input/journey-springfield/testset/testset/img620.jpg
# /kaggle/input/journey-springfield/testset/testset/img412.jpg
# /kaggle/input/journey-springfield/testset/testset/img12.jpg
# /kaggle/input/journey-springfield/testset/testset/img761.jpg
# /kaggle/input/journey-springfield/testset/testset/img919.jpg
# /kaggle/input/journey-springfield/testset/testset/img686.jpg
# /kaggle/input/journey-springfield/testset/testset/img922.jpg
# /kaggle/input/journey-springfield/testset/testset/img717.jpg
# /kaggle/input/journey-springfield/testset/testset/img657.jpg
# /kaggle/input/journey-springfield/testset/testset/img237.jpg
# /kaggle/input/journey-springfield/testset/testset/img861.jpg
# /kaggle/input/journey-springfield/testset/testset/img24.jpg
# /kaggle/input/journey-springfield/testset/testset/img612.jpg
# /kaggle/input/journey-springfield/testset/testset/img727.jpg
# /kaggle/input/journey-springfield/testset/testset/img123.jpg
# /kaggle/input/journey-springfield/testset/testset/img896.jpg
# /kaggle/input/journey-springfield/testset/testset/img271.jpg
# /kaggle/input/journey-springfield/testset/testset/img539.jpg
# /kaggle/input/journey-springfield/testset/testset/img93.jpg
# /kaggle/input/journey-springfield/testset/testset/img92.jpg
# /kaggle/input/journey-springfield/testset/testset/img118.jpg
# /kaggle/input/journey-springfield/testset/testset/img953.jpg
# /kaggle/input/journey-springfield/testset/testset/img209.jpg
# /kaggle/input/journey-springfield/testset/testset/img920.jpg
# /kaggle/input/journey-springfield/testset/testset/img826.jpg
# /kaggle/input/journey-springfield/testset/testset/img610.jpg
# /kaggle/input/journey-springfield/testset/testset/img739.jpg
# /kaggle/input/journey-springfield/testset/testset/img388.jpg
# /kaggle/input/journey-springfield/testset/testset/img831.jpg
# /kaggle/input/journey-springfield/testset/testset/img543.jpg
# /kaggle/input/journey-springfield/testset/testset/img455.jpg
# /kaggle/input/journey-springfield/testset/testset/img10.jpg
# /kaggle/input/journey-springfield/testset/testset/img698.jpg
# /kaggle/input/journey-springfield/testset/testset/img600.jpg
# /kaggle/input/journey-springfield/testset/testset/img518.jpg
# /kaggle/input/journey-springfield/testset/testset/img200.jpg
# /kaggle/input/journey-springfield/testset/testset/img305.jpg
# /kaggle/input/journey-springfield/testset/testset/img59.jpg
# /kaggle/input/journey-springfield/testset/testset/img336.jpg
# /kaggle/input/journey-springfield/testset/testset/img652.jpg
# /kaggle/input/journey-springfield/testset/testset/img332.jpg
# /kaggle/input/journey-springfield/testset/testset/img105.jpg
# /kaggle/input/journey-springfield/testset/testset/img603.jpg
# /kaggle/input/journey-springfield/testset/testset/img671.jpg
# /kaggle/input/journey-springfield/testset/testset/img933.jpg
# /kaggle/input/journey-springfield/testset/testset/img226.jpg
# /kaggle/input/journey-springfield/testset/testset/img533.jpg
# /kaggle/input/journey-springfield/testset/testset/img662.jpg
# /kaggle/input/journey-springfield/testset/testset/img990.jpg
# /kaggle/input/journey-springfield/testset/testset/img147.jpg
# /kaggle/input/journey-springfield/testset/testset/img661.jpg
# /kaggle/input/journey-springfield/testset/testset/img987.jpg
# /kaggle/input/journey-springfield/testset/testset/img98.jpg
# /kaggle/input/journey-springfield/testset/testset/img537.jpg
# /kaggle/input/journey-springfield/testset/testset/img149.jpg
# /kaggle/input/journey-springfield/testset/testset/img225.jpg
# /kaggle/input/journey-springfield/testset/testset/img315.jpg
# /kaggle/input/journey-springfield/testset/testset/img236.jpg
# /kaggle/input/journey-springfield/testset/testset/img938.jpg
# /kaggle/input/journey-springfield/testset/testset/img449.jpg
# /kaggle/input/journey-springfield/testset/testset/img731.jpg
# /kaggle/input/journey-springfield/testset/testset/img302.jpg
# /kaggle/input/journey-springfield/testset/testset/img954.jpg
# /kaggle/input/journey-springfield/testset/testset/img909.jpg
# /kaggle/input/journey-springfield/testset/testset/img28.jpg
# /kaggle/input/journey-springfield/testset/testset/img278.jpg
# /kaggle/input/journey-springfield/testset/testset/img857.jpg
# /kaggle/input/journey-springfield/testset/testset/img902.jpg
# /kaggle/input/journey-springfield/testset/testset/img101.jpg
# /kaggle/input/journey-springfield/testset/testset/img81.jpg
# /kaggle/input/journey-springfield/testset/testset/img971.jpg
# /kaggle/input/journey-springfield/testset/testset/img843.jpg
# /kaggle/input/journey-springfield/testset/testset/img885.jpg
# /kaggle/input/journey-springfield/testset/testset/img350.jpg
# /kaggle/input/journey-springfield/testset/testset/img473.jpg
# /kaggle/input/journey-springfield/testset/testset/img103.jpg
# /kaggle/input/journey-springfield/testset/testset/img702.jpg
# /kaggle/input/journey-springfield/testset/testset/img755.jpg
# /kaggle/input/journey-springfield/testset/testset/img958.jpg
# /kaggle/input/journey-springfield/testset/testset/img303.jpg
# /kaggle/input/journey-springfield/testset/testset/img238.jpg
# /kaggle/input/journey-springfield/testset/testset/img581.jpg
# /kaggle/input/journey-springfield/testset/testset/img644.jpg
# /kaggle/input/journey-springfield/testset/testset/img120.jpg
# /kaggle/input/journey-springfield/testset/testset/img374.jpg
# /kaggle/input/journey-springfield/testset/testset/img381.jpg
# /kaggle/input/journey-springfield/testset/testset/img756.jpg
# /kaggle/input/journey-springfield/testset/testset/img172.jpg
# /kaggle/input/journey-springfield/testset/testset/img866.jpg
# /kaggle/input/journey-springfield/testset/testset/img605.jpg
# /kaggle/input/journey-springfield/testset/testset/img480.jpg
# /kaggle/input/journey-springfield/testset/testset/img433.jpg
# /kaggle/input/journey-springfield/testset/testset/img165.jpg
# /kaggle/input/journey-springfield/testset/testset/img474.jpg
# /kaggle/input/journey-springfield/testset/testset/img719.jpg
# /kaggle/input/journey-springfield/testset/testset/img343.jpg
# /kaggle/input/journey-springfield/testset/testset/img255.jpg
# /kaggle/input/journey-springfield/testset/testset/img126.jpg
# /kaggle/input/journey-springfield/testset/testset/img319.jpg
# /kaggle/input/journey-springfield/testset/testset/img694.jpg
# /kaggle/input/journey-springfield/testset/testset/img481.jpg
# /kaggle/input/journey-springfield/testset/testset/img931.jpg
# /kaggle/input/journey-springfield/testset/testset/img112.jpg
# /kaggle/input/journey-springfield/testset/testset/img199.jpg
# /kaggle/input/journey-springfield/testset/testset/img463.jpg
# /kaggle/input/journey-springfield/testset/testset/img747.jpg
# /kaggle/input/journey-springfield/testset/testset/img622.jpg
# /kaggle/input/journey-springfield/testset/testset/img638.jpg
# /kaggle/input/journey-springfield/testset/testset/img621.jpg
# /kaggle/input/journey-springfield/testset/testset/img129.jpg
# /kaggle/input/journey-springfield/testset/testset/img484.jpg
# /kaggle/input/journey-springfield/testset/testset/img152.jpg
# /kaggle/input/journey-springfield/testset/testset/img191.jpg
# /kaggle/input/journey-springfield/testset/testset/img709.jpg
# /kaggle/input/journey-springfield/testset/testset/img791.jpg
# /kaggle/input/journey-springfield/testset/testset/img645.jpg
# /kaggle/input/journey-springfield/testset/testset/img359.jpg
# /kaggle/input/journey-springfield/testset/testset/img963.jpg
# /kaggle/input/journey-springfield/testset/testset/img347.jpg
# /kaggle/input/journey-springfield/testset/testset/img15.jpg
# /kaggle/input/journey-springfield/testset/testset/img411.jpg
# /kaggle/input/journey-springfield/testset/testset/img956.jpg
# /kaggle/input/journey-springfield/testset/testset/img615.jpg
# /kaggle/input/journey-springfield/testset/testset/img639.jpg
# /kaggle/input/journey-springfield/testset/testset/img619.jpg
# /kaggle/input/journey-springfield/testset/testset/img984.jpg
# /kaggle/input/journey-springfield/testset/testset/img14.jpg
# /kaggle/input/journey-springfield/testset/testset/img668.jpg
# /kaggle/input/journey-springfield/testset/testset/img407.jpg
# /kaggle/input/journey-springfield/testset/testset/img341.jpg
# /kaggle/input/journey-springfield/testset/testset/img867.jpg
# /kaggle/input/journey-springfield/testset/testset/img75.jpg
# /kaggle/input/journey-springfield/testset/testset/img115.jpg
# /kaggle/input/journey-springfield/testset/testset/img743.jpg
# /kaggle/input/journey-springfield/testset/testset/img181.jpg
# /kaggle/input/journey-springfield/testset/testset/img80.jpg
# /kaggle/input/journey-springfield/testset/testset/img972.jpg
# /kaggle/input/journey-springfield/testset/testset/img300.jpg
# /kaggle/input/journey-springfield/testset/testset/img66.jpg
# /kaggle/input/journey-springfield/testset/testset/img29.jpg
# /kaggle/input/journey-springfield/testset/testset/img598.jpg
# /kaggle/input/journey-springfield/testset/testset/img646.jpg
# /kaggle/input/journey-springfield/testset/testset/img914.jpg
# /kaggle/input/journey-springfield/testset/testset/img219.jpg
# /kaggle/input/journey-springfield/testset/testset/img466.jpg
# /kaggle/input/journey-springfield/testset/testset/img189.jpg
# /kaggle/input/journey-springfield/testset/testset/img522.jpg
# /kaggle/input/journey-springfield/testset/testset/img310.jpg
# /kaggle/input/journey-springfield/testset/testset/img495.jpg
# /kaggle/input/journey-springfield/testset/testset/img526.jpg
# /kaggle/input/journey-springfield/testset/testset/img440.jpg
# /kaggle/input/journey-springfield/testset/testset/img163.jpg
# /kaggle/input/journey-springfield/testset/testset/img585.jpg
# /kaggle/input/journey-springfield/testset/testset/img804.jpg
# /kaggle/input/journey-springfield/testset/testset/img553.jpg
# /kaggle/input/journey-springfield/testset/testset/img472.jpg
# /kaggle/input/journey-springfield/testset/testset/img69.jpg
# /kaggle/input/journey-springfield/testset/testset/img723.jpg
# /kaggle/input/journey-springfield/testset/testset/img618.jpg
# /kaggle/input/journey-springfield/testset/testset/img32.jpg
# /kaggle/input/journey-springfield/testset/testset/img724.jpg
# /kaggle/input/journey-springfield/testset/testset/img61.jpg
# /kaggle/input/journey-springfield/testset/testset/img955.jpg
# /kaggle/input/journey-springfield/testset/testset/img684.jpg
# /kaggle/input/journey-springfield/testset/testset/img218.jpg
# /kaggle/input/journey-springfield/testset/testset/img793.jpg
# /kaggle/input/journey-springfield/testset/testset/img611.jpg
# /kaggle/input/journey-springfield/testset/testset/img111.jpg
# /kaggle/input/journey-springfield/testset/testset/img689.jpg
# /kaggle/input/journey-springfield/testset/testset/img836.jpg
# /kaggle/input/journey-springfield/testset/testset/img367.jpg
# /kaggle/input/journey-springfield/testset/testset/img382.jpg
# /kaggle/input/journey-springfield/testset/testset/img364.jpg
# /kaggle/input/journey-springfield/testset/testset/img889.jpg
# /kaggle/input/journey-springfield/testset/testset/img590.jpg
# /kaggle/input/journey-springfield/testset/testset/img780.jpg
# /kaggle/input/journey-springfield/testset/testset/img267.jpg
# /kaggle/input/journey-springfield/testset/testset/img471.jpg
# /kaggle/input/journey-springfield/testset/testset/img5.jpg
# /kaggle/input/journey-springfield/testset/testset/img135.jpg
# /kaggle/input/journey-springfield/testset/testset/img46.jpg
# /kaggle/input/journey-springfield/testset/testset/img489.jpg
# /kaggle/input/journey-springfield/testset/testset/img400.jpg
# /kaggle/input/journey-springfield/testset/testset/img771.jpg
# /kaggle/input/journey-springfield/testset/testset/img344.jpg
# /kaggle/input/journey-springfield/testset/testset/img577.jpg
# /kaggle/input/journey-springfield/testset/testset/img829.jpg
# /kaggle/input/journey-springfield/testset/testset/img317.jpg
# /kaggle/input/journey-springfield/testset/testset/img932.jpg
# /kaggle/input/journey-springfield/testset/testset/img185.jpg
# /kaggle/input/journey-springfield/testset/testset/img487.jpg
# /kaggle/input/journey-springfield/testset/testset/img178.jpg
# /kaggle/input/journey-springfield/testset/testset/img666.jpg
# /kaggle/input/journey-springfield/testset/testset/img720.jpg
# /kaggle/input/journey-springfield/testset/testset/img372.jpg
# /kaggle/input/journey-springfield/testset/testset/img736.jpg
# /kaggle/input/journey-springfield/testset/testset/img977.jpg
# /kaggle/input/journey-springfield/testset/testset/img67.jpg
# /kaggle/input/journey-springfield/testset/testset/img746.jpg
# /kaggle/input/journey-springfield/testset/testset/img369.jpg
# /kaggle/input/journey-springfield/testset/testset/img712.jpg
# /kaggle/input/journey-springfield/testset/testset/img318.jpg
# /kaggle/input/journey-springfield/testset/testset/img335.jpg
# /kaggle/input/journey-springfield/testset/testset/img457.jpg
# /kaggle/input/journey-springfield/testset/testset/img630.jpg
# /kaggle/input/journey-springfield/testset/testset/img513.jpg
# /kaggle/input/journey-springfield/testset/testset/img628.jpg
# /kaggle/input/journey-springfield/testset/testset/img201.jpg
# /kaggle/input/journey-springfield/testset/testset/img687.jpg
# /kaggle/input/journey-springfield/testset/testset/img292.jpg
# /kaggle/input/journey-springfield/testset/testset/img567.jpg
# /kaggle/input/journey-springfield/testset/testset/img757.jpg
# /kaggle/input/journey-springfield/testset/testset/img530.jpg
# /kaggle/input/journey-springfield/testset/testset/img520.jpg
# /kaggle/input/journey-springfield/testset/testset/img299.jpg
# /kaggle/input/journey-springfield/testset/testset/img858.jpg
# /kaggle/input/journey-springfield/testset/testset/img252.jpg
# /kaggle/input/journey-springfield/testset/testset/img211.jpg
# /kaggle/input/journey-springfield/testset/testset/img406.jpg
# /kaggle/input/journey-springfield/testset/testset/img557.jpg
# /kaggle/input/journey-springfield/testset/testset/img345.jpg
# /kaggle/input/journey-springfield/testset/testset/img905.jpg
# /kaggle/input/journey-springfield/testset/testset/img375.jpg
# /kaggle/input/journey-springfield/testset/testset/img962.jpg
# /kaggle/input/journey-springfield/testset/testset/img3.jpg
# /kaggle/input/journey-springfield/testset/testset/img512.jpg
# /kaggle/input/journey-springfield/testset/testset/img245.jpg
# /kaggle/input/journey-springfield/testset/testset/img4.jpg
# /kaggle/input/journey-springfield/testset/testset/img950.jpg
# /kaggle/input/journey-springfield/testset/testset/img673.jpg
# /kaggle/input/journey-springfield/testset/testset/img132.jpg
# /kaggle/input/journey-springfield/testset/testset/img542.jpg
# /kaggle/input/journey-springfield/testset/testset/img923.jpg
# /kaggle/input/journey-springfield/testset/testset/img925.jpg
# /kaggle/input/journey-springfield/testset/testset/img714.jpg
# /kaggle/input/journey-springfield/testset/testset/img71.jpg
# /kaggle/input/journey-springfield/testset/testset/img884.jpg
# /kaggle/input/journey-springfield/testset/testset/img393.jpg
# /kaggle/input/journey-springfield/testset/testset/img959.jpg
# /kaggle/input/journey-springfield/testset/testset/img168.jpg
# /kaggle/input/journey-springfield/testset/testset/img824.jpg
# /kaggle/input/journey-springfield/testset/testset/img427.jpg
# /kaggle/input/journey-springfield/testset/testset/img929.jpg
# /kaggle/input/journey-springfield/testset/testset/img100.jpg
# /kaggle/input/journey-springfield/testset/testset/img616.jpg
# /kaggle/input/journey-springfield/testset/testset/img293.jpg
# /kaggle/input/journey-springfield/testset/testset/img597.jpg
# /kaggle/input/journey-springfield/testset/testset/img384.jpg
# /kaggle/input/journey-springfield/testset/testset/img145.jpg
# /kaggle/input/journey-springfield/testset/testset/img496.jpg
# /kaggle/input/journey-springfield/testset/testset/img559.jpg
# /kaggle/input/journey-springfield/testset/testset/img216.jpg
# /kaggle/input/journey-springfield/testset/testset/img142.jpg
# /kaggle/input/journey-springfield/testset/testset/img91.jpg
# /kaggle/input/journey-springfield/testset/testset/img874.jpg
# /kaggle/input/journey-springfield/testset/testset/img432.jpg
# /kaggle/input/journey-springfield/testset/testset/img886.jpg
# /kaggle/input/journey-springfield/testset/testset/img538.jpg
# /kaggle/input/journey-springfield/testset/testset/img842.jpg
# /kaggle/input/journey-springfield/testset/testset/img137.jpg
# /kaggle/input/journey-springfield/testset/testset/img848.jpg
# /kaggle/input/journey-springfield/testset/testset/img357.jpg
# /kaggle/input/journey-springfield/testset/testset/img970.jpg
# /kaggle/input/journey-springfield/testset/testset/img851.jpg
# /kaggle/input/journey-springfield/testset/testset/img560.jpg
# /kaggle/input/journey-springfield/testset/testset/img23.jpg
# /kaggle/input/journey-springfield/testset/testset/img44.jpg
# /kaggle/input/journey-springfield/testset/testset/img631.jpg
# /kaggle/input/journey-springfield/testset/testset/img573.jpg
# /kaggle/input/journey-springfield/testset/testset/img678.jpg
# /kaggle/input/journey-springfield/testset/testset/img558.jpg
# /kaggle/input/journey-springfield/testset/testset/img409.jpg
# /kaggle/input/journey-springfield/testset/testset/img535.jpg
# /kaggle/input/journey-springfield/testset/testset/img794.jpg
# /kaggle/input/journey-springfield/testset/testset/img734.jpg
# /kaggle/input/journey-springfield/testset/testset/img898.jpg
# /kaggle/input/journey-springfield/testset/testset/img744.jpg
# /kaggle/input/journey-springfield/testset/testset/img171.jpg
# /kaggle/input/journey-springfield/testset/testset/img892.jpg
# /kaggle/input/journey-springfield/testset/testset/img782.jpg
# /kaggle/input/journey-springfield/testset/testset/img951.jpg
# /kaggle/input/journey-springfield/testset/testset/img37.jpg
# /kaggle/input/journey-springfield/testset/testset/img817.jpg
# /kaggle/input/journey-springfield/testset/testset/img121.jpg
# /kaggle/input/journey-springfield/testset/testset/img656.jpg
# /kaggle/input/journey-springfield/testset/testset/img43.jpg
# /kaggle/input/journey-springfield/testset/testset/img320.jpg
# /kaggle/input/journey-springfield/testset/testset/img60.jpg
# /kaggle/input/journey-springfield/testset/testset/img308.jpg
# /kaggle/input/journey-springfield/testset/testset/img387.jpg
# /kaggle/input/journey-springfield/testset/testset/img629.jpg
# /kaggle/input/journey-springfield/testset/testset/img536.jpg
# /kaggle/input/journey-springfield/testset/testset/img458.jpg
# /kaggle/input/journey-springfield/testset/testset/img371.jpg
# /kaggle/input/journey-springfield/testset/testset/img765.jpg
# /kaggle/input/journey-springfield/testset/testset/img239.jpg
# /kaggle/input/journey-springfield/testset/testset/img809.jpg
# /kaggle/input/journey-springfield/testset/testset/img841.jpg
# /kaggle/input/journey-springfield/testset/testset/img819.jpg
# /kaggle/input/journey-springfield/testset/testset/img468.jpg
# /kaggle/input/journey-springfield/testset/testset/img732.jpg
# /kaggle/input/journey-springfield/testset/testset/img465.jpg
# /kaggle/input/journey-springfield/testset/testset/img436.jpg
# /kaggle/input/journey-springfield/testset/testset/img713.jpg
# /kaggle/input/journey-springfield/testset/testset/img705.jpg
# /kaggle/input/journey-springfield/testset/testset/img814.jpg
# /kaggle/input/journey-springfield/testset/testset/img485.jpg
# /kaggle/input/journey-springfield/testset/testset/img222.jpg
# /kaggle/input/journey-springfield/testset/testset/img869.jpg
# /kaggle/input/journey-springfield/testset/testset/img701.jpg
# /kaggle/input/journey-springfield/testset/testset/img122.jpg
# /kaggle/input/journey-springfield/testset/testset/img49.jpg
# /kaggle/input/journey-springfield/testset/testset/img354.jpg
# /kaggle/input/journey-springfield/testset/testset/img939.jpg
# /kaggle/input/journey-springfield/testset/testset/img55.jpg
# /kaggle/input/journey-springfield/testset/testset/img617.jpg
# /kaggle/input/journey-springfield/testset/testset/img912.jpg
# /kaggle/input/journey-springfield/testset/testset/img911.jpg
# /kaggle/input/journey-springfield/testset/testset/img214.jpg
# /kaggle/input/journey-springfield/testset/testset/img441.jpg
# /kaggle/input/journey-springfield/testset/testset/img78.jpg
# /kaggle/input/journey-springfield/testset/testset/img399.jpg
# /kaggle/input/journey-springfield/testset/testset/img813.jpg
# /kaggle/input/journey-springfield/testset/testset/img270.jpg
# /kaggle/input/journey-springfield/testset/testset/img944.jpg
# /kaggle/input/journey-springfield/testset/testset/img758.jpg
# /kaggle/input/journey-springfield/testset/testset/img865.jpg
# /kaggle/input/journey-springfield/testset/testset/img549.jpg
# /kaggle/input/journey-springfield/testset/testset/img108.jpg
# /kaggle/input/journey-springfield/testset/testset/img849.jpg
# /kaggle/input/journey-springfield/testset/testset/img161.jpg
# /kaggle/input/journey-springfield/testset/testset/img730.jpg
# /kaggle/input/journey-springfield/testset/testset/img22.jpg
# /kaggle/input/journey-springfield/testset/testset/img781.jpg
# /kaggle/input/journey-springfield/testset/testset/img834.jpg
# /kaggle/input/journey-springfield/testset/testset/img442.jpg
# /kaggle/input/journey-springfield/testset/testset/img193.jpg
# /kaggle/input/journey-springfield/testset/testset/img294.jpg
# /kaggle/input/journey-springfield/testset/testset/img95.jpg
# /kaggle/input/journey-springfield/testset/testset/img571.jpg
# /kaggle/input/journey-springfield/testset/testset/img125.jpg
# /kaggle/input/journey-springfield/testset/testset/img30.jpg
# /kaggle/input/journey-springfield/testset/testset/img845.jpg
# /kaggle/input/journey-springfield/testset/testset/img877.jpg
# /kaggle/input/journey-springfield/testset/testset/img231.jpg
# /kaggle/input/journey-springfield/testset/testset/img70.jpg
# /kaggle/input/journey-springfield/testset/testset/img642.jpg
# /kaggle/input/journey-springfield/testset/testset/img378.jpg
# /kaggle/input/journey-springfield/testset/testset/img772.jpg
# /kaggle/input/journey-springfield/testset/testset/img19.jpg
# /kaggle/input/journey-springfield/testset/testset/img419.jpg
# /kaggle/input/journey-springfield/testset/testset/img486.jpg
# /kaggle/input/journey-springfield/testset/testset/img806.jpg
# /kaggle/input/journey-springfield/testset/testset/img333.jpg
# /kaggle/input/journey-springfield/testset/testset/img766.jpg
# /kaggle/input/journey-springfield/testset/testset/img334.jpg
# /kaggle/input/journey-springfield/testset/testset/img291.jpg
# /kaggle/input/journey-springfield/testset/testset/img927.jpg
# /kaggle/input/journey-springfield/testset/testset/img506.jpg
# /kaggle/input/journey-springfield/testset/testset/img90.jpg
# /kaggle/input/journey-springfield/testset/testset/img494.jpg
# /kaggle/input/journey-springfield/testset/testset/img402.jpg
# /kaggle/input/journey-springfield/testset/testset/img288.jpg
# /kaggle/input/journey-springfield/testset/testset/img283.jpg
# /kaggle/input/journey-springfield/testset/testset/img710.jpg
# /kaggle/input/journey-springfield/testset/testset/img654.jpg
# /kaggle/input/journey-springfield/testset/testset/img443.jpg
# /kaggle/input/journey-springfield/testset/testset/img65.jpg
# /kaggle/input/journey-springfield/testset/testset/img6.jpg
# /kaggle/input/journey-springfield/testset/testset/img253.jpg
# /kaggle/input/journey-springfield/testset/testset/img109.jpg
# /kaggle/input/journey-springfield/testset/testset/img674.jpg
# /kaggle/input/journey-springfield/testset/testset/img856.jpg
# /kaggle/input/journey-springfield/testset/testset/img394.jpg
# /kaggle/input/journey-springfield/testset/testset/img423.jpg
# /kaggle/input/journey-springfield/testset/testset/img404.jpg
# /kaggle/input/journey-springfield/testset/testset/img508.jpg
# /kaggle/input/journey-springfield/testset/testset/img454.jpg
# /kaggle/input/journey-springfield/testset/testset/img477.jpg
# /kaggle/input/journey-springfield/testset/testset/img176.jpg
# /kaggle/input/journey-springfield/testset/testset/img830.jpg
# /kaggle/input/journey-springfield/testset/testset/img658.jpg
# /kaggle/input/journey-springfield/testset/testset/img316.jpg
# /kaggle/input/journey-springfield/testset/testset/img891.jpg
# /kaggle/input/journey-springfield/testset/testset/img541.jpg
# /kaggle/input/journey-springfield/testset/testset/img221.jpg
# /kaggle/input/journey-springfield/testset/testset/img815.jpg
# /kaggle/input/journey-springfield/testset/testset/img180.jpg
# /kaggle/input/journey-springfield/testset/testset/img897.jpg
# /kaggle/input/journey-springfield/testset/testset/img762.jpg
# /kaggle/input/journey-springfield/testset/testset/img786.jpg
# /kaggle/input/journey-springfield/testset/testset/img38.jpg
# /kaggle/input/journey-springfield/testset/testset/img980.jpg
# /kaggle/input/journey-springfield/testset/testset/img546.jpg
# /kaggle/input/journey-springfield/testset/testset/img871.jpg
# /kaggle/input/journey-springfield/testset/testset/img792.jpg
# /kaggle/input/journey-springfield/testset/testset/img415.jpg
# /kaggle/input/journey-springfield/testset/testset/img389.jpg
# /kaggle/input/journey-springfield/testset/testset/img706.jpg
# /kaggle/input/journey-springfield/testset/testset/img801.jpg
# /kaggle/input/journey-springfield/testset/testset/img808.jpg
# /kaggle/input/journey-springfield/testset/testset/img198.jpg
# /kaggle/input/journey-springfield/testset/testset/img627.jpg
# /kaggle/input/journey-springfield/testset/testset/img934.jpg
# /kaggle/input/journey-springfield/testset/testset/img26.jpg
# /kaggle/input/journey-springfield/testset/testset/img852.jpg
# /kaggle/input/journey-springfield/testset/testset/img213.jpg
# /kaggle/input/journey-springfield/testset/testset/img564.jpg
# /kaggle/input/journey-springfield/testset/testset/img448.jpg
# /kaggle/input/journey-springfield/testset/testset/img850.jpg
# /kaggle/input/journey-springfield/testset/testset/img233.jpg
# /kaggle/input/journey-springfield/testset/testset/img753.jpg
# /kaggle/input/journey-springfield/testset/testset/img73.jpg
# /kaggle/input/journey-springfield/testset/testset/img947.jpg
# /kaggle/input/journey-springfield/testset/testset/img554.jpg
# /kaggle/input/journey-springfield/testset/testset/img56.jpg
# /kaggle/input/journey-springfield/testset/testset/img875.jpg
# /kaggle/input/journey-springfield/testset/testset/img88.jpg
# /kaggle/input/journey-springfield/testset/testset/img787.jpg
# /kaggle/input/journey-springfield/testset/testset/img750.jpg
# /kaggle/input/journey-springfield/testset/testset/img311.jpg
# /kaggle/input/journey-springfield/testset/testset/img528.jpg
# /kaggle/input/journey-springfield/testset/testset/img329.jpg
# /kaggle/input/journey-springfield/testset/testset/img114.jpg
# /kaggle/input/journey-springfield/testset/testset/img230.jpg
# /kaggle/input/journey-springfield/testset/testset/img754.jpg
# /kaggle/input/journey-springfield/testset/testset/img13.jpg
# /kaggle/input/journey-springfield/testset/testset/img968.jpg
# /kaggle/input/journey-springfield/testset/testset/img106.jpg
# /kaggle/input/journey-springfield/testset/testset/img368.jpg
# /kaggle/input/journey-springfield/testset/testset/img748.jpg
# /kaggle/input/journey-springfield/testset/testset/img941.jpg
# /kaggle/input/journey-springfield/testset/testset/img1.jpg
# /kaggle/input/journey-springfield/testset/testset/img25.jpg
# /kaggle/input/journey-springfield/testset/testset/img880.jpg
# /kaggle/input/journey-springfield/testset/testset/img703.jpg
# /kaggle/input/journey-springfield/testset/testset/img386.jpg
# /kaggle/input/journey-springfield/testset/testset/img250.jpg
# /kaggle/input/journey-springfield/testset/testset/img391.jpg
# /kaggle/input/journey-springfield/testset/testset/img864.jpg
# /kaggle/input/journey-springfield/testset/testset/img444.jpg
# /kaggle/input/journey-springfield/testset/testset/img261.jpg
# /kaggle/input/journey-springfield/testset/testset/img127.jpg
# /kaggle/input/journey-springfield/testset/testset/img76.jpg
# /kaggle/input/journey-springfield/testset/testset/img823.jpg
# /kaggle/input/journey-springfield/testset/testset/img54.jpg
# /kaggle/input/journey-springfield/testset/testset/img608.jpg
# /kaggle/input/journey-springfield/testset/testset/img588.jpg
# /kaggle/input/journey-springfield/testset/testset/img769.jpg
# /kaggle/input/journey-springfield/testset/testset/img770.jpg
# /kaggle/input/journey-springfield/testset/testset/img276.jpg
# /kaggle/input/journey-springfield/testset/testset/img527.jpg
# /kaggle/input/journey-springfield/testset/testset/img397.jpg
# /kaggle/input/journey-springfield/testset/testset/img882.jpg
# /kaggle/input/journey-springfield/testset/testset/img899.jpg
# /kaggle/input/journey-springfield/testset/testset/img456.jpg
# /kaggle/input/journey-springfield/testset/testset/img807.jpg
# /kaggle/input/journey-springfield/testset/testset/img309.jpg
# /kaggle/input/journey-springfield/testset/testset/img281.jpg
# /kaggle/input/journey-springfield/testset/testset/img635.jpg
# /kaggle/input/journey-springfield/testset/testset/img596.jpg
# /kaggle/input/journey-springfield/testset/testset/img240.jpg
# /kaggle/input/journey-springfield/testset/testset/img604.jpg
# /kaggle/input/journey-springfield/testset/testset/img504.jpg
# /kaggle/input/journey-springfield/testset/testset/img708.jpg
# /kaggle/input/journey-springfield/testset/testset/img906.jpg
# /kaggle/input/journey-springfield/testset/testset/img650.jpg
# /kaggle/input/journey-springfield/testset/testset/img488.jpg
# /kaggle/input/journey-springfield/testset/testset/img84.jpg
# /kaggle/input/journey-springfield/testset/testset/img462.jpg
# /kaggle/input/journey-springfield/testset/testset/img624.jpg
# /kaggle/input/journey-springfield/testset/testset/img429.jpg
# /kaggle/input/journey-springfield/testset/testset/img562.jpg
# /kaggle/input/journey-springfield/testset/testset/img306.jpg
# /kaggle/input/journey-springfield/testset/testset/img380.jpg
# /kaggle/input/journey-springfield/testset/testset/img515.jpg
# /kaggle/input/journey-springfield/testset/testset/img107.jpg
# /kaggle/input/journey-springfield/testset/testset/img248.jpg
# /kaggle/input/journey-springfield/testset/testset/img469.jpg
# /kaggle/input/journey-springfield/testset/testset/img556.jpg
# /kaggle/input/journey-springfield/testset/testset/img873.jpg
# /kaggle/input/journey-springfield/testset/testset/img208.jpg
# /kaggle/input/journey-springfield/testset/testset/img592.jpg
# /kaggle/input/journey-springfield/testset/testset/img623.jpg
# /kaggle/input/journey-springfield/testset/testset/img11.jpg
# /kaggle/input/journey-springfield/testset/testset/img825.jpg
# /kaggle/input/journey-springfield/testset/testset/img497.jpg
# /kaggle/input/journey-springfield/testset/testset/img355.jpg
# /kaggle/input/journey-springfield/testset/testset/img641.jpg
# /kaggle/input/journey-springfield/testset/testset/img655.jpg
# /kaggle/input/journey-springfield/testset/testset/img79.jpg
# /kaggle/input/journey-springfield/testset/testset/img531.jpg
# /kaggle/input/journey-springfield/testset/testset/img952.jpg
# ...
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0473.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0551.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0690.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0569.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0495.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0344.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0682.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0605.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0227.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0530.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0464.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0182.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0323.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0328.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0438.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0265.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0753.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0159.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0866.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0324.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0353.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0389.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0363.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0233.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0108.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0413.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0395.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0424.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0299.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0707.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0051.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0102.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0562.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0043.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0573.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0598.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0197.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0194.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0266.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0122.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0483.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0364.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0208.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0366.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0213.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0779.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0044.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0057.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0877.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0761.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0307.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0420.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0191.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0135.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0308.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0123.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0035.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0871.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0098.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0200.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0071.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0296.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0357.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0781.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0662.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0294.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0606.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0113.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0336.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0235.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0620.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0330.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0820.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0065.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0140.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0777.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0261.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0315.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0209.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0015.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0511.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0644.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0732.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0510.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0273.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0240.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0172.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0076.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0337.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0134.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0405.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0776.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0399.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0094.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0441.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0616.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0232.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0595.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0780.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0112.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0442.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0354.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0234.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0426.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0210.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0716.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0400.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0581.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0029.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0118.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0797.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0101.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0695.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0830.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0498.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0059.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0480.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0422.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0167.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0215.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0807.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0512.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0099.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0453.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0155.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0516.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0377.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0137.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0649.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0245.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0449.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0223.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0206.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0286.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0375.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0648.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0814.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0305.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0448.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0727.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0540.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0591.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0762.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0794.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0505.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0070.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0487.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0284.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0176.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0156.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0668.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0469.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0646.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0385.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0676.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0626.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0255.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0390.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0302.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0165.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0433.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0848.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0142.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0163.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0217.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0688.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0371.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0298.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0816.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0032.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0254.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0398.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0160.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0778.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0802.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0515.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0525.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0747.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0115.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0478.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0419.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0128.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0061.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0625.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0347.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0145.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0713.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0876.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0832.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0647.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0578.jpg
# /kaggle/input/journey-springfield/train/simpsons_dataset/sideshow_bob/pic_0408.jpg

# %%
import torch
import torchvision.utils as utils
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torchvision.models as models
import torch.nn as nn
import torch.optim as optim
import numpy as np
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
transformations = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
train_set = datasets.ImageFolder("/kaggle/input/journey-springfield/train/simpsons_dataset", transform = transformations)
test_set = datasets.ImageFolder("/kaggle/input/journey-springfield/testset", transform = transformations)

# %%
from pathlib import Path

TRAIN_DIR = Path('../input/journey-springfield/train/simpsons_dataset')
TEST_DIR = Path('../input/journey-springfield/testset/testset')

train_files = sorted(list(TRAIN_DIR.rglob('*.jpg')))
train_val_labels = [path.parent.name for path in train_files]
test_files = sorted(list(TEST_DIR.rglob('*.jpg')))

# %%
trainloader = torch.utils.data.DataLoader(train_set, 
                                          batch_size=4,
                                          shuffle=True, 
                                          num_workers=2)


testloader = torch.utils.data.DataLoader(test_set, 
                                         batch_size=4,
                                         shuffle=False, 
                                         num_workers=2)

# %%
# функция для показа изображения

def imshow(img):
    img = img / 2 + 0.5     # денормализуем
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %%
classes = pd.Series([path.parent.name for path in train_files]).unique()
classes
# Out:
# array(['abraham_grampa_simpson', 'agnes_skinner',
#        'apu_nahasapeemapetilon', 'barney_gumble', 'bart_simpson',
#        'carl_carlson', 'charles_montgomery_burns', 'chief_wiggum',
#        'cletus_spuckler', 'comic_book_guy', 'disco_stu', 'edna_krabappel',
#        'fat_tony', 'gil', 'groundskeeper_willie', 'homer_simpson',
#        'kent_brockman', 'krusty_the_clown', 'lenny_leonard',
#        'lionel_hutz', 'lisa_simpson', 'maggie_simpson', 'marge_simpson',
#        'martin_prince', 'mayor_quimby', 'milhouse_van_houten',
#        'miss_hoover', 'moe_szyslak', 'ned_flanders', 'nelson_muntz',
#        'otto_mann', 'patty_bouvier', 'principal_skinner',
#        'professor_john_frink', 'rainier_wolfcastle', 'ralph_wiggum',
#        'selma_bouvier', 'sideshow_bob', 'sideshow_mel', 'snake_jailbird',
#        'troy_mcclure', 'waylon_smithers'], dtype=object)

# %%
# получаем несколько случайных тренировочных изображений
dataiter = iter(trainloader)
images, labels = next(dataiter)

# показываем изображения
plt.grid(False)
plt.xticks([])
plt.yticks([])
imshow(utils.make_grid(images))
# печатаем метки

print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# marge_simpson bart_simpson lisa_simpson principal_skinner

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class Net(nn.Module):

    def __init__(self, n_classes):
        super().__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=8, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv4 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv5 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=96, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )

        self.out = nn.Linear(96 * 5 * 5, n_classes)


    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)

        x = x.view(x.size(0), -1)
        logits = self.out(x)
        return logits
net = Net(len(classes))

# %%
criterion = nn.CrossEntropyLoss()

optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
# -*- coding: utf-8 -*-

# проходим в цикле по набору данных несколько раз
for epoch in range(2):  

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # получаем вводные данные
        inputs, labels = data

        # обнуляем параметр gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # печатаем статистику
        running_loss += loss.item()
        if i % 2000 == 1999:    # печатаем каждые 2000 мини-пакетов
            print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / 2000))
            running_loss = 0.0

print('Тренировка завершена')
# Out:
# [1,  2000] loss: 2.921
# [1,  4000] loss: 2.268
# [2,  2000] loss: 1.581
# [2,  4000] loss: 1.387
# Тренировка завершена

# %%
dataiter = iter(testloader)
images, labels = next(dataiter)
outputs = net(images)

# печатаем изображения
plt.grid(False)
plt.xticks([])
plt.yticks([])
imshow(utils.make_grid(images))

_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' | '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
# Out:
# Predicted:  nelson_muntz | bart_simpson | ned_flanders | chief_wiggum

# %%
def predict(net, testloader):
    with torch.no_grad():
        logits = []
        dataiter = iter(testloader)
          
        for inputs in testloader:
            images, labels = next(dataiter)
            net.eval()
            outputs = net(images)
            logits.append(outputs)

    probs = nn.functional.softmax(torch.cat(logits), dim=-1).numpy()
    return probs

# %%
probs = predict(net, testloader)

preds = [classes[i] for i in probs.argmax(axis=-1)]

# %%
test_filenames = [f'img{i}' for i in range(len(preds))]

# %%
pd.DataFrame({
    "Id": test_filenames,
    "Expected": preds
}).to_csv("submission.csv", index=False)
